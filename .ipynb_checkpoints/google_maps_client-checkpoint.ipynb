# %%
import requests
from urllib.parse import urlencode
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
GOOGLE_API_KEY = "AIzaSyCQLnUynI4y2NUzr1behot71QopvpZy3QU"

# %% [markdown]
# ### Google Maps Client API

# %%
class GoogleMapsClient(object):
    lat = None
    lng = None
    data_type = 'json'
    location_query = None
    api_key = None
    
    def __init__(self, api_key=None, address=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        if api_key == None:
            raise Exception("API key is required")
        self.api_key = api_key
        self.location_query = address
        if self.location_query != None:
            self.extract_lat_lng()
    
    def extract_lat_lng(self, location=None):
        loc_query = self.location_query
        if location !=  None:
            loc_query = location
        data_type = "json"
        endpoint = f"https://maps.googleapis.com/maps/api/geocode/{self.data_type}"
        params = {"address": loc_query, "key": self.api_key}
        url_params = urlencode(params)
        url = f"{endpoint}?{url_params}"
        r = requests.get(url)
        if r.status_code not in range(200, 299):
            return {}
        lat_lng = {}
        try:
            lat_lng = r.json()["results"][0]["geometry"]["location"]
        except:
            pass
        lat, lng = lat_lng.get("lat"), lat_lng.get("lng")
        self.lat = lat
        self.lng = lng
        return lat, lng
    
    def search(self, keyword="Attractions", radius=1000, location=None):
        lat, lng = self.lat, self.lng
        if location != None:
            lat, lng = self.extract_lat_lng(location);
        places_endpoint = f"https://maps.googleapis.com/maps/api/place/nearbysearch/{self.data_type}"
        params = {
            "key": self.api_key,
            "location": f"{lat},{lng}",
            "radius": radius,
            "keyword": keyword
        }
        params_encoded = urlencode(params)
        places_url = f"{places_endpoint}?{params_encoded}"

        r = requests.get(places_url)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def detail(self, place_id="ChIJK1-_KkxXa4gRazRkyTLNKBw"):
        detail_base_endpoint = "https://maps.googleapis.com/maps/api/place/details/json"
        detail_params = {
            "place_id": f"{place_id}",
            "fields": "name,website,url,opening_hours",
            "key": self.api_key
        }

        detail_params_encoded = urlencode(detail_params)
        detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"

        r = requests.get(detail_url)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
client = GoogleMapsClient(api_key=GOOGLE_API_KEY, address="Indianapolis, IN")

# print(client.search("Food", radius=2000, location="Fishers, IN").keys())
# print(client.search("Food", radius=2000, location="Indianapolis, IN")["results"][0]['opening_hours'])
print(client.search("Food", radius=2000, location="Indianapolis, IN")["results"][0]['user_ratings_total'])
# print(client.detail(place_id="ChIJlQbGKUxXa4gRegV6S5T6kO0")['result']['opening_hours']['periods'][1])
# Out:
# 3

# %%
# In a 3 mile radius of the lat, lng of Indianapolis
results = client.search("Attractions", radius=5000, location="Indianapolis, IN")["results"]
results += client.search("Gift Shops", radius=5000, location="Indianapolis, IN")["results"]
"""
print(f"#,Name,Address,Rating,Website,Type")
for i in range(len(results)):
    curr = results[i]
    try:
        website = client.detail(place_id=curr['place_id'])['result']['website']
        print(f"{i+1},{curr['name']},{curr['vicinity']},{curr['rating']},{website},{curr['types'][0]}\n")
    except:
        print(f"{i+1},{curr['name']},{curr['vicinity']},{curr['rating']},NULL,{curr['types'][0]}\n")
"""
with open('mapData.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Name','Open','Closed','Address','Rating','# of ratings','Website','Type'])
    for i in range(len(results)):
        curr = results[i]
        # omit if rating is equal to 0 stars
        if curr['rating'] == 0:
            continue
        try:
            details = client.detail(place_id=curr['place_id'])['result']
            website = details['website']
            open_time = f"{details['opening_hours']['periods'][1]['open']['time'][:2]}:{details['opening_hours']['periods'][1]['open']['time'][2:]}"
            close_time = f"{details['opening_hours']['periods'][1]['close']['time'][:2]}:{details['opening_hours']['periods'][1]['close']['time'][2:]}"
        except:
            website = "NULL"
            open_time = "NULL"
            close_time = "NULL"
        writer.writerow([curr['name'], open_time, close_time, curr['vicinity'], curr['rating'], curr['user_ratings_total'], website, curr['types'][0]])

# %% [markdown]
# ### Data on local attractions and stores from Google Maps Geocoding and Places API

# %%
dataset = pd.read_csv("mapData.csv")
dataset.sort_values('Rating', ascending=False)
# Out:
#                                      Name   Open Closed  \
# 30          All Occasions Gifts & Flowers    NaN    NaN
# 10                          Garfield Lake    NaN    NaN
# 26                        Stomping Ground  11:00  18:00
# 23                               Artisans  12:00  18:00
# 19                 Tuggle's Gifts & Goods  11:00  18:00
# 28              Homespun: Modern Handmade  10:00  20:00
# 17           The Escape Room Indianapolis  13:00  22:00
# 0                           Central Canal    NaN    NaN
# 20                     Silver In the City  10:00  20:00
# 7           Indiana War Memorial & Museum  09:00  17:00
# 2                  White River State Park  05:00  23:00
# 13         Indiana Medical History Museum  10:00  16:00
# 14                Indianapolis Canal Walk  07:00  20:00
# 1   The Children's Museum of Indianapolis  10:00  17:00
# 3                Rhythm! Discovery Center  10:00  17:00
# 22     Indiana State Museum, Gallery Shop  10:00  17:00
# 18                           Global Gifts  10:00  18:00
# 9              Garfield Park Conservatory  10:00  17:00
# 8                           Garfield Park  10:00  17:00
# 29                  Circle City Souvenirs  23:00  19:00
# 5                    Indiana State Museum  10:00  17:00
# 11                          Central Canal    NaN    NaN
# 15                       Eiteljorg Museum  10:00  17:00
# 4                        Indianapolis Zoo  09:00  16:00
# 25             Indianapolis Zoo Gift Shop  09:00  16:00
# 16                   American Legion Mall  07:00  23:00
# 12                          Highland Park  08:00  21:00
# 24                             Pumkinfish  10:30  21:00
# 21                          Gift Shop One    NaN    NaN
# 6                               Catacombs    NaN    NaN
# 27                      The Indiana Store  10:00  17:00
#
#                                               Address  Rating  # of ratings  \
# 30                       3837 E 10th St, Indianapolis     5.0            23
# 10                                       Indianapolis     5.0             2
# 26                     1625 Nowland Ave, Indianapolis     5.0            36
# 23                429 Massachusetts Ave, Indianapolis     5.0             5
# 19                    1029 Virginia Ave, Indianapolis     5.0            12
# 28                869 Massachusetts Ave, Indianapolis     4.8           202
# 17            200 S Meridian St STE 220, Indianapolis     4.8          1863
# 0                                        Indianapolis     4.8           197
# 20                434 Massachusetts Ave, Indianapolis     4.7           414
# 7                      55 E Michigan St, Indianapolis     4.7          2372
# 2                   801 W Washington St, Indianapolis     4.7          4461
# 13                   3270 Kirkbride Way, Indianapolis     4.7           395
# 14                           Canal Walk, Indianapolis     4.7          2288
# 1                    3000 N Meridian St, Indianapolis     4.7         13122
# 3   Claypool Court Building, 110 W Washington St A...     4.7           284
# 22  650 W Washington St L.S. Ayres Tea Room, India...     4.7             9
# 18                446 Massachusetts Ave, Indianapolis     4.7            65
# 9                  2505 Conservatory Dr, Indianapolis     4.7          1313
# 8                        2345 Pagoda Dr, Indianapolis     4.6          3099
# 29                     49 W Maryland St, Indianapolis     4.6            31
# 5                   650 W Washington St, Indianapolis     4.6          3337
# 11                           Canal Walk, Indianapolis     4.6            36
# 15                  500 W Washington St, Indianapolis     4.6          1657
# 4                  1200 W Washington St, Indianapolis     4.5         16731
# 25                 1200 W Washington St, Indianapolis     4.5            61
# 16                700 N Pennsylvania St, Indianapolis     4.5           519
# 12                   1100 E New York St, Indianapolis     4.5           249
# 24           906 Carrollton Ave Ste 440, Indianapolis     4.1            30
# 21  Embassy suites, 110 W Washington St 3rd floor,...     3.9             9
# 6                       222 E Market St, Indianapolis     3.8            79
# 27                  650 W Washington St, Indianapolis     3.8             5
#
#                                               Website                Type
# 30                                                NaN             florist
# 10                                                NaN  tourist_attraction
# 26                     http://stompinggroundindy.com/               store
# 23                       http://www.artisansindy.com/         art_gallery
# 19                   http://tugglesgiftsandgoods.com/               store
# 28                      https://www.homespunindy.com/         art_gallery
# 17                        https://escaperoomindy.com/  tourist_attraction
# 0                                                 NaN  tourist_attraction
# 20                    http://www.silverinthecity.com/       jewelry_store
# 7                https://www.indianawarmemorials.org/  tourist_attraction
# 2                https://www.whiteriverstatepark.org/  tourist_attraction
# 13                               http://www.imhm.org/              museum
# 14               https://www.whiteriverstatepark.org/                park
# 1                    https://www.childrensmuseum.org/  tourist_attraction
# 3                   http://rhythmdiscoverycenter.org/              museum
# 22         https://www.indianamuseum.org/experiences/               store
# 18                     https://www.globalgiftsft.com/               store
# 9        https://www.garfieldgardensconservatory.org/  tourist_attraction
# 8             http://funfinder.indy.gov/#/details/134                park
# 29               https://www.circlecitysouvenirs.com/               store
# 5                       http://www.indianamuseum.org/              museum
# 11                                                NaN                park
# 15                          http://www.eiteljorg.org/  tourist_attraction
# 4                     http://www.indianapoliszoo.com/                 zoo
# 25  https://www.muzemerch.com/partner/indianapolis...               store
# 16                     http://www.in.gov/iwm/2331.htm                park
# 12              http://funfinder.indy.gov/#/details/9                park
# 24                         http://www.pumkinfish.com/               store
# 21                                                NaN               store
# 6                                                 NaN  tourist_attraction
# 27                                     http://in.gov/               store

# %% [markdown]
# ### Rating Analysis
# As we can see here, the ratings of attractions throughout Indianapolis tend to hover around the 4.5 - 4.7 range. As we move outside of the inter-quartile range, we can see that the data points outside the IQR tend to have less volume of user reviews which could be the reasoning behind the low average user rating. To be the most sure about which destinations to go to, staying within or above the IQR would be the most reasonable decision.

# %%
plt.boxplot(dataset.Rating)
plt.show()

# %% [markdown]
# ### Type of Destination Analysis

# %%
plt.hist(dataset.Type)
plt.show()
